# %%
par_stor_name = "<<your storage account name>>"
par_container_name = "<<your file system name on storage account>>"

configs = {
  "fs.azure.account.auth.type": "CustomAccessToken",
  "fs.azure.account.custom.token.provider.class": spark.conf.get("spark.databricks.passthrough.adls.gen2.tokenProviderClassName")
}

# Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(
  source = "abfss://" + par_container_name + "@" + par_stor_name + ".dfs.core.windows.net/",
  mount_point = "/mnt/hcmount1",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: True</div>

# %%
dbutils.fs.ls("/mnt/hcmount1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [FileInfo(path=&#39;dbfs:/mnt/hcmount1/testcsv.txt&#39;, name=&#39;testcsv.txt&#39;, size=61)]</div>

# %%
df2 = spark.read.csv("/mnt/hcmount1/testcsv.txt")
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th></tr></thead><tbody><tr><td>firstname</td><td> lastname</td></tr><tr><td>Rene</td><td> Bremer</td></tr><tr><td>Thom</td><td> Bremer</td></tr><tr><td>Stef</td><td> Bremer</td></tr></tbody></table></div>

# %%
# %sh
ls -l /dbfs/mnt/hcmount1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total 1
# -rwxrwxrwx 1 root root 75 Apr  6 12:41 mount.err
# </div>

# %%
import os
os.listdir('/dbfs/mnt/hcmount1')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [&#39;mount.err&#39;]</div>

# %%
# read the file
#with open("/mnt/hcmount1/testcsv.txt", "r") as f_read:
#  for line in f_read:
#    print(line)
dbutils.fs.unmount("/mnt/hcmount1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/hcmount1 has been unmounted.
# Out[1]: True</div>
